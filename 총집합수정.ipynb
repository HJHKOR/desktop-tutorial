# %%
#최종적으로 사용할 데이터를 선정 후, 데이터 정리와 dash를 이용한 홈페이지 프로토타입 제작까지 실행해보았습니다.

#한재홍-df

import pandas as pd
import numpy as np

import dash
from dash import dcc, html
from dash.dependencies import Input, Output, State

import plotly.graph_objects as go
from plotly.colors import DEFAULT_PLOTLY_COLORS

# %%
# 데이터 호출
df = pd.read_csv('C:/analysis/github datamining/datamining/데마종합데이터1.csv', encoding = 'euc-kr')
df
# Out:
#    도시  공교육만족점수  공공문화여가시설만족도  교육인프라점수합산  재정자립도  소비자물가지수  경제점수합산  대중교통접근시간  \
# 0  부산    319.8        409.1         13   46.1   113.22       9        19
# 1  대구    319.9        419.9         12   44.6   113.48       7        21
# 2  인천    293.2        433.9          8   50.3   113.86       7        18
# 3  광주    305.8        452.2          7   40.8   113.62       4        20
# 4  대전    323.1        434.5         13   39.9   112.93       7        17
# 5  울산    296.8        410.0         10   49.6   113.51       8        19
#
#    도로포장률  교통점수합산  응급실도착시간  면적당병상수  보건점수합산   범죄율  면적당경찰관서수  치안점수합산  대기오염물질배출량  \
# 0   98.3       6     4.42    91.7       8  3.39      9.46       7  129920075
# 1   99.1      10     4.06    44.9      10  3.00      7.02       5   81408842
# 2   98.0       3     4.82    34.0       3  2.99      7.06       8  168795267
# 3  100.0      11     4.26    78.6      10  2.94      7.98      10   42941462
# ...

# %%
#fig1	교육, 인프라	공교육 만족도

df1 = df.sort_values(by='공교육만족점수',ascending=False)

trace1 = go.Bar(
    x=df1['도시'],
    y=df1['공교육만족점수'],
    name='공교육 평가 점수',
    orientation='v')

data = [trace1]

layout = go.Layout(title = '광역시별 공교육 만족도', yaxis=dict(range=[290, 325]))

fig1 = go.Figure(data, layout)
fig1.show()

# %%
#fig2	교육, 인프라	공공문화시설만족도

df2=df.sort_values(by='공공문화여가시설만족도',ascending=False)

trace=go.Bar(
    x=df2['도시'],
    y=df2['공공문화여가시설만족도'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 공공문화여가시설 서비스 만족도',
                  yaxis = dict(range=[400,453]))
               
fig2=go.Figure(data, layout)
fig2.show()

# %%
#fig3	교육, 인프라	종합

df3=df.sort_values(by='교육인프라점수합산',ascending=False)

trace=go.Bar(
    x=df3['도시'],
    y=df3['교육인프라점수합산'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 교육,인프라 점수 총합')
               
fig3=go.Figure(data, layout)
fig3.show()

# %%
#fig4	경제	재정자립도

df4=df.sort_values(by='재정자립도',ascending=False)

trace=go.Bar(
    x=df4['도시'],
    y=df4['재정자립도'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 재정자립도', yaxis=dict(range=[35, 55]))
               
fig4=go.Figure(data, layout)
fig4.show()

# %%
#fig5	경제	소비자 물가 지수

df5=df.sort_values(by='소비자물가지수',ascending=True)

trace=go.Bar(
    x=df5['도시'],
    y=df5['소비자물가지수'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 소비자물가지수', yaxis=dict(range=[110, 115]))
               
fig5=go.Figure(data, layout)
fig5.show()

# %%
#fig6	경제	종합
df6=df.sort_values(by='경제점수합산',ascending=False)

trace=go.Bar(
    x=df6['도시'],
    y=df6['경제점수합산'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 경제 점수 총합')

fig6=go.Figure(data, layout)
fig6.show()

# %%
#fig7	교통	대중교통 접근시간

df7=df.sort_values(by='대중교통접근시간',ascending=False)

trace=go.Bar(
    x=df7['도시'],
    y=df7['대중교통접근시간'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 대중교통접근시간', yaxis=dict(range=[15, 23]))

fig7=go.Figure(data, layout)
fig7.show()

# %%
#fig8	교통	도로포장률

df8=df.sort_values(by='도로포장률',ascending=False)

trace=go.Bar(
    x=df8['도시'],
    y=df8['도로포장률'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 도로포장률', yaxis=dict(range=[95, 100]))

fig8=go.Figure(data, layout)
fig8.show()

# %%
#fig9	교통	종합

df9=df.sort_values(by='교통점수합산',ascending=False)

trace=go.Bar(
    x=df9['도시'],
    y=df9['교통점수합산'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 교통 점수 종합')

fig9=go.Figure(data, layout)
fig9.show()

# %%
#fig10	보건	응급실도착시간

df10=df.sort_values(by='응급실도착시간',ascending=True)

trace=go.Bar(
    x=df10['도시'],
    y=df10['응급실도착시간'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 응급실도착시간')

fig10=go.Figure(data, layout)
fig10.show()

# %%
#fig11	보건	의사수

df11=df.sort_values(by='면적당병상수',ascending=False)

trace=go.Bar(
    x=df11['도시'],
    y=df11['면적당병상수'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 면적당병상수')

fig11=go.Figure(data, layout)
fig11.show()

# %%
#fig12	보건	종합

df12=df.sort_values(by='보건점수합산',ascending=False)

trace=go.Bar(
    x=df12['도시'],
    y=df12['보건점수합산'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 보건 점수 종합')

fig12=go.Figure(data, layout)
fig12.show()

# %%
#fig13	치안	범죄율

df13=df.sort_values(by='범죄율',ascending=True)

trace=go.Bar(
    x=df13['도시'],
    y=df13['범죄율'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 범죄율')

fig13=go.Figure(data, layout)
fig13.show()

# %%
#fig14	치안	경찰관서수

df14=df.sort_values(by='면적당경찰관서수',ascending=False)

trace=go.Bar(
    x=df14['도시'],
    y=df14['면적당경찰관서수'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 면적당경찰관서수')

fig14=go.Figure(data, layout)
fig14.show()

# %%
#fig15	치안	종합
df15=df.sort_values(by='치안점수합산',ascending=False)

trace=go.Bar(
    x=df15['도시'],
    y=df15['치안점수합산'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 치안 점수 종합')

fig15=go.Figure(data, layout)
fig15.show()

# %%
#fig16	환경	대기오염물질 배출량

df16=df.sort_values(by='대기오염물질배출량',ascending=True)

trace=go.Bar(
    x=df16['도시'],
    y=df16['대기오염물질배출량'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 대기오염물질배출량')

fig16=go.Figure(data, layout)
fig16.show()

# %%
#fig17	환경	종합

df17=df.sort_values(by='환경점수합산',ascending=False)

trace=go.Bar(
    x=df17['도시'],
    y=df17['환경점수합산'])
    
data=[trace]
    
layout=go.Layout(title='광역시별 환경 점수 종합')

fig17=go.Figure(data, layout)
fig17.show()

# %%
#fig18	종합순위 1
import plotly.express as px

file11=pd.read_csv("C:/analysis/github datamining/datamining/11점수합산.csv", encoding='euc-kr')

fig18 = px.bar(file11, y="도시", x=['교육,인프라', '교통', '경제','범죄','환경','보건'], title="점수 합산", orientation='h')
fig18.show()

# %%
#fig19	종합순위 2

file22=pd.read_csv("C:/analysis/github datamining/datamining/가보자점수최종11세로.csv", encoding='euc-kr')

fig19 = px.bar(file22, x="도시", y="점수", color="도시",
  animation_frame="분류", animation_group="도시", range_y=[0,45])
fig19.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 1000
fig19.show()

# %%
app = dash.Dash(__name__) # app 정의
app.title = ('데이터마이닝 웹페이지 프로토타입 1호기')

server = app.server

app.layout = html.Div([
 html.H2('데이터마이닝 웹페이지 프로토타입 1호기',
            style={'textAlign': 'center', 'marginBottom': 10, 'marginTop': 10}),
    
     
        html.Div([
            dcc.Graph(
                id='bar-chart-1',
                figure=fig1
            ),
        ], style={'width': '33%', 'display': 'inline-block'}),
        
        html.Div([
            dcc.Graph(
                id='bar-chart-2',
                figure=fig2
            ),
        ], style={'width': '33%', 'display': 'inline-block'}),
        
         html.Div([
            dcc.Graph(
                id='bar-chart-3',
                figure=fig3
            ),
        ], style={'width': '34%', 'display': 'inline-block'}),
    
      html.Div([
            dcc.Graph(
                id='bar-chart-4',
                figure=fig4
            ),
        ], style={'width': '33%', 'display': 'inline-block'}),
    
      html.Div([
            dcc.Graph(
                id='bar-chart-5',
                figure=fig5
            ),
        ], style={'width': '33%', 'display': 'inline-block'}),
    
      html.Div([
            dcc.Graph(
                id='bar-chart-6',
                figure=fig6
            ),
        ], style={'width': '34%', 'display': 'inline-block'}),
    
    
     html.Div([
            dcc.Graph(
                id='bar-chart-7',
                figure=fig7
            ),
        ], style={'width': '25%', 'display': 'inline-block'}),
    
     html.Div([
            dcc.Graph(
                id='bar-chart-8',
                figure=fig8
            ),
        ], style={'width': '25%', 'display': 'inline-block'}),
    
     html.Div([
            dcc.Graph(
                id='bar-chart-9',
                figure=fig9
            ),
        ], style={'width': '25%', 'display': 'inline-block'}),
    
     html.Div([
            dcc.Graph(
                id='bar-chart-10',
                figure=fig10
            ),
        ], style={'width': '25%', 'display': 'inline-block'}),
    
     html.Div([
            dcc.Graph(
                id='bar-chart-11',
                figure=fig11
            ),
        ], style={'width': '33%', 'display': 'inline-block'}),
    
     html.Div([
            dcc.Graph(
                id='bar-chart-12',
                figure=fig12
            ),
        ], style={'width': '33%', 'display': 'inline-block'}),
    
     html.Div([
            dcc.Graph(
                id='bar-chart-13',
                figure=fig13
            ),
        ], style={'width': '34%', 'display': 'inline-block'}),
    
    html.Div([
            dcc.Graph(
                id='bar-chart-14',
                figure=fig14
            ),
        ], style={'width': '100%', 'display': 'inline-block'}),
        
    html.Div([
            dcc.Graph(
                id='bar-chart-15',
                figure=fig15
            ),
        ], style={'width': '100%', 'display': 'inline-block'}),
        
    html.Div([
            dcc.Graph(
                id='bar-chart-16',
                figure=fig16
            ),
        ], style={'width': '100%', 'display': 'inline-block'}),
        
    html.Div([
            dcc.Graph(
                id='bar-chart-17',
                figure=fig17
            ),
        ], style={'width': '100%', 'display': 'inline-block'}),
        
    html.Div([
            dcc.Graph(
                id='bar-chart-18',
                figure=fig18
            ),
        ], style={'width': '100%', 'display': 'inline-block'}),
        
    html.Div([
            dcc.Graph(
                id='bar-chart-19',
                figure=fig19
            ),
        ], style={'width': '100%', 'display': 'inline-block'})
        
    ])

if __name__ == '__main__':
     app.run_server(debug=True, port=8053)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8053/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import geopandas as gpd
gdf = gpd.read_file("C:/analysis/github datamining/datamining/Z_NGII_N3A_G0010000.shp")
gdf1 = gdf.loc[[4,5,6,7,10,11]]
gdf2 =gdf1[['NAME','geometry']]

# %%
geo= gdf2.merge(file22, left_on = 'NAME' ,right_on = '도시',how = 'inner').to_crs(epsg =4326)

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.graph_objects as go
import geopandas as gpd
import pandas as pd

# ... (your data loading and other code)

# Assume you have the GeoDataFrame 'geo' with the required columns
# You've provided a scatter_fig and the layout configuration

# Reproject GeoDataFrame to a projected CRS
# Example: WGS 84 / UTM zone 33N (EPSG:32633)
projected_crs = 'EPSG:32633'
geo = geo.to_crs(projected_crs)

# Scattermapbox
scatter_fig = go.Scattermapbox(
    lat=geo['geometry'].centroid.y,
    lon=geo['geometry'].centroid.x,
    mode='markers',
    marker=dict(
        size=geo['합계']*2,
        color=geo['합계'],
        colorscale="pubu"
    ),
)

# Map initialization
initial_lat = geo['geometry'].centroid.y.mean()
initial_lon = geo['geometry'].centroid.x.mean()
initial_zoom = 5.825
mapbox_style = 'carto-positron'

# Create Figure
fig = go.Figure(scatter_fig,
                go.Layout(mapbox=dict(center=dict(lat=initial_lat, lon=initial_lon),
                                      style=mapbox_style,
                                      zoom=initial_zoom),
                           showlegend=False)
                )

# Update layout
fig.update_layout(mapbox=dict(center=dict(lat=initial_lat, lon=initial_lon),
                              style=mapbox_style,
                              zoom=initial_zoom),
                  showlegend=False,
                  height=600,
                  width=600
                 )

# Dash app initialization
app = dash.Dash(__name__)
app.title = 'Your Dashboard Title'

# App layout
app.layout = html.Div([
    # 1st layer
    html.Div([
        html.H2('Sales Dashboard with Dash',
                style={'textAlign': 'center', 'marginBottom': 10, 'marginTop': 10}),
        # ... (other components in the 1st layer)
    ], style={'float': 'left', 'display': 'inline-block', 'width': '65%'}),

    # 2nd layer
    html.Div([
        # Dropdowns, Map, Sankey
        dcc.Dropdown(
            id='id_year',
            options=[{'label': i, 'value': i} for i in geo['year'].unique()],  # assuming 'year' is a column in your GeoDataFrame
            value=max(geo['year']),
            style={'width': '50%'}
        ),
        dcc.Graph(id='map', figure=fig),  # Add the map to the layout
        dcc.Graph(id='sankey')
    ], style={'float': 'right', 'width': '35%'}),
])

# Add your other callbacks or configurations as needed

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True, port=8053)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '합계'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
scatter_fig = go.Scattermapbox(
    lat=geo['geometry'].centroid.y,  # 중심점의 위도
    lon=geo['geometry'].centroid.x,  # 중심점의 경도
    mode='markers',
    marker=dict(
        size=geo['합계']*2,
        color=geo['합계'],
        colorscale="pubu"
    ),
)

# 지도 초기 위치 설정
initial_lat = geo['geometry'].centroid.y.mean()
initial_lon = geo['geometry'].centroid.x.mean()

# 지도 초기 확대/축소 수준 설정
initial_zoom = 5.825

# 지도 스타일 설정
mapbox_style = 'carto-positron'

# go.Figure 객체 생성
fig = go.Figure(scatter_fig,  # scatter_fig만으로도 충분합니다.
                go.Layout(mapbox=dict(center=dict(lat=initial_lat, lon=initial_lon),
                                       style=mapbox_style,
                                       zoom=initial_zoom),
                           showlegend=False)
                )

# 레이아웃 업데이트
fig.update_layout(mapbox=dict(center=dict(lat=initial_lat, lon=initial_lon),
                              style=mapbox_style,
                              zoom=initial_zoom),
                  showlegend=False,
                  height=600,  # 그림의 높이 조절
                  width=600    # 그림의 너비 조절
                 )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 2
#       1 scatter_fig = go.Scattermapbox(
# ----> 2     lat=geo['geometry'].centroid.y,  # 중심점의 위도
#       3     lon=geo['geometry'].centroid.x,  # 중심점의 경도
#       4     mode='markers',
#       5     marker=dict(
#       6         size=geo['합계']*2,
#       7         color=geo['합계'],
#       8         colorscale="pubu"
#       9     ),
#      10 )
#      12 # 지도 초기 위치 설정
#      13 initial_lat = geo['geometry'].centroid.y.mean()
#
# NameError: name 'geo' is not defined

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.graph_objects as go
import geopandas as gpd
import pandas as pd

# ... (your data loading and other code)

# Assume you have the GeoDataFrame 'geo' with the required columns
# You've provided a scatter_fig and the layout configuration

# Reproject GeoDataFrame to a projected CRS
# Example: WGS 84 / UTM zone 33N (EPSG:32633)
projected_crs = 'EPSG:32633'
geo = geo.to_crs(projected_crs)

# Scattermapbox
scatter_fig = go.Scattermapbox(
    lat=geo['geometry'].centroid.y,
    lon=geo['geometry'].centroid.x,
    mode='markers',
    marker=dict(
        size=geo['합계']*2,
        color=geo['합계'],
        colorscale="pubu"
    ),
)

# Map initialization
initial_lat = geo['geometry'].centroid.y.mean()
initial_lon = geo['geometry'].centroid.x.mean()
initial_zoom = 5.825
mapbox_style = 'carto-positron'

# Create Figure
fig = go.Figure(scatter_fig,
                go.Layout(mapbox=dict(center=dict(lat=initial_lat, lon=initial_lon),
                                      style=mapbox_style,
                                      zoom=initial_zoom),
                           showlegend=False)
                )

# Update layout
fig.update_layout(mapbox=dict(center=dict(lat=initial_lat, lon=initial_lon),
                              style=mapbox_style,
                              zoom=initial_zoom),
                  showlegend=False,
                  height=600,
                  width=600
                 )

# Dash app initialization
app = dash.Dash(__name__)
app.title = 'Your Dashboard Title'

# App layout
app.layout = html.Div([
    # 1st layer
    html.Div([
        html.H2('Sales Dashboard with Dash',
                style={'textAlign': 'center', 'marginBottom': 10, 'marginTop': 10}),
        # ... (other components in the 1st layer)
    ], style={'float': 'left', 'display': 'inline-block', 'width': '65%'}),

    # 2nd layer
    html.Div([
        # Dropdowns, Map, Sankey
        dcc.Dropdown(
            id='id_year',
            options=[{'label': i, 'value': i} for i in geo['year'].unique()],  # assuming 'year' is a column in your GeoDataFrame
            value=max(geo['year']),
            style={'width': '50%'}
        ),
        dcc.Graph(id='map', figure=fig),  # Add the map to the layout
        dcc.Graph(id='sankey')
    ], style={'float': 'right', 'width': '35%'}),
])

# Add your other callbacks or configurations as needed

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True, port=8053)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[102], line 16
#       8 # ... (your data loading and other code)
#       9
#      10 # Assume you have the GeoDataFrame 'geo' with the required columns
#    (...)
#      13 # Reproject GeoDataFrame to a projected CRS
#      14 # Example: WGS 84 / UTM zone 33N (EPSG:32633)
#      15 projected_crs = 'EPSG:32633'
# ---> 16 geo = geo.to_crs(projected_crs)
#      18 # Scattermapbox
#      19 scatter_fig = go.Scattermapbox(
#      20     lat=geo['geometry'].centroid.y,
#      21     lon=geo['geometry'].centroid.x,
#    (...)
#      27     ),
#      28 )
#
# NameError: name 'geo' is not defined
